# %%
# !pip install flask pyngrok --quiet

# %%
# !pip install pytz
# Out:
# Requirement already satisfied: pytz in c:\users\123\anaconda3\lib\site-packages (2024.1)

# %%
# Install dependencies
# !pip install flask pyngrok pytz requests --quiet

# Imports
from flask import Flask, request, Response
from datetime import datetime
from pytz import timezone
from pyngrok import ngrok
import threading
import requests
import os
from collections import defaultdict

# Globals
log_file = "/content/open_log.txt"
open_counts = defaultdict(int)

app = Flask(__name__)

@app.route('/track')
def track():
    email_id = request.args.get('id', 'unknown')
    ip = request.headers.get('X-Forwarded-For', request.remote_addr)

    # Get current time in IST
    utc_now = datetime.utcnow()
    ist = timezone('Asia/Kolkata')
    ist_time = utc_now.replace(tzinfo=timezone('UTC')).astimezone(ist)
    timestamp = ist_time.strftime('%Y-%m-%d %H:%M:%S %Z')

    # Increment open count
    open_counts[email_id] += 1

    # Log info (no location)
    with open(log_file, "a") as f:
        f.write(
            f"Email ID: {email_id}\n"
            f"Opened at: {timestamp}\n"
            f"IP Address: {ip}\n"
            f"Open Count: {open_counts[email_id]}\n\n"
        )

    # Return 1x1 transparent GIF
    pixel = (
        b'\x47\x49\x46\x38\x39\x61\x01\x00\x01\x00\x80\x00\x00\x00\x00\x00'
        b'\xff\xff\xff\x21\xf9\x04\x01\x00\x00\x00\x00\x2c\x00\x00\x00\x00'
        b'\x01\x00\x01\x00\x00\x02\x02\x4c\x01\x00\x3b'
    )
    return pixel, 200, {'Content-Type': 'image/gif'}

# ✅ Web Dashboard route (no location column)
@app.route('/dashboard')
def dashboard():
    if not os.path.exists(log_file):
        return "No logs yet."

    with open(log_file, 'r') as f:
        log_data = f.read()

    # Format as HTML table
    entries = log_data.strip().split('\n\n')
    table_rows = ""
    for entry in entries:
        lines = entry.split('\n')
        values = [line.split(': ', 1)[1] if ': ' in line else '' for line in lines]
        if len(values) >= 4:
            table_rows += f"<tr><td>{values[0]}</td><td>{values[1]}</td><td>{values[2]}</td><td>{values[3]}</td></tr>"

    html = f"""
    <html>
    <head>
        <title>Tracking Dashboard</title>
        <style>
            table {{border-collapse: collapse; width: 100%;}}
            th, td {{border: 1px solid black; padding: 8px; text-align: left;}}
            th {{background-color: #f2f2f2;}}
        </style>
    </head>
    <body>
        <h2>Email Tracking Dashboard</h2>
        <table>
            <tr><th>Email ID</th><th>Opened At</th><th>IP Address</th><th>Open Count</th></tr>
            {table_rows}
        </table>
        <br>
        <a href="/export">📥 Download CSV</a>
    </body>
    </html>
    """
    return html

# ✅ Export logs as CSV (no location column)
@app.route('/export')
def export_logs():
    if not os.path.exists(log_file):
        return "No logs yet."

    with open(log_file, 'r') as f:
        log_data = f.read()

    # Convert to CSV format
    entries = log_data.strip().split('\n\n')
    csv_data = "Email ID,Opened At,IP Address,Open Count\n"
    for entry in entries:
        lines = entry.split('\n')
        values = [line.split(': ', 1)[1] if ': ' in line else '' for line in lines]
        if len(values) >= 4:
            csv_data += f"{values[0]},{values[1]},{values[2]},{values[3]}\n"

    return Response(
        csv_data,
        mimetype="text/csv",
        headers={"Content-Disposition": "attachment;filename=open_log.csv"}
    )

# Start Flask app in thread
def run_flask():
    app.run(port=5001)

threading.Thread(target=run_flask).start()

# Setup ngrok
ngrok.set_auth_token("2zLuCtN3zALATwZlVc2yps42Tj2_3nPDhDQ5GpJtJPZc7A5Tx")
public_url = ngrok.connect(5001)
print("✅ Tracking Pixel URL:")
print(public_url.public_url + "/track?id=user123")
print("📊 Dashboard URL:")
print(public_url.public_url + "/dashboard")

# Send email
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5001
# Press CTRL+C to quit
# ✅ Tracking Pixel URL:
# https://df2537f4f40a.ngrok-free.app/track?id=user123
# 📊 Dashboard URL:
# https://df2537f4f40a.ngrok-free.app/dashboard
# t=2025-11-13T01:09:15+0530 lvl=warn msg="failed to check for update" obj=updater err="Post \"https://update.equinox.io/check\": context deadline exceeded"
# 127.0.0.1 - - [13/Nov/2025 01:09:18] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Nov/2025 01:09:19] "GET /favicon.ico HTTP/1.1" 404 -

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

sender_email = "praneethtirumalasetty811@gmail.com"
receiver_email = "mohammednorulashik@gmail.com"
app_password = "**** **** **** ****"

msg = MIMEMultipart("alternative")
msg["Subject"] = "Tracked Email"
msg["From"] = sender_email
msg["To"] = receiver_email

html = f"""
<html>
  <body>
    <p>Hello!</p>
    <p>This email contains a tracking pixel.</p>
    <img src="https://3ff262974445.ngrok-free.app/track?id=mohammednorulashik@gmail.com" width="1" height="1" style="display:none;" />
    <p>If image is blocked, click <a href="https://3ff262974445.ngrok-free.app/track?id=mohammednorulashik@gmail.com">this link</a>.</p>
  </body>
</html>
"""

msg.attach(MIMEText(html, "html"))

with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
    server.login(sender_email, app_password)
    server.sendmail(sender_email, receiver_email, msg.as_string())

print("📤 Email sent.")
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[5], line 28
#      25 msg.attach(MIMEText(html, "html"))
#      27 with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
# ---> 28     server.login(sender_email, app_password)
#      29     server.sendmail(sender_email, receiver_email, msg.as_string())
#      31 print("📤 Email sent.")
#
# File c:\Users\123\anaconda3\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File c:\Users\123\anaconda3\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
#     742     # 235 == 'Authentication successful'
#     743     # 503 == 'Error: already authenticated'
#     744     if code in (235, 503):
#
# File c:\Users\123\anaconda3\Lib\smtplib.py:662, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     660 if code in (235, 503):
#     661     return (code, resp)
# --> 662 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-7b73ae09668sm4486104b3a.69 - gsmtp')
# t=2025-11-13T02:25:17+0530 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=ac46ceea4a11 err="read tcp [2402:3a80:1bbf:ed:976:3648:a8da:2fda]:54964->[2600:1f16:d83:1202:dec4:7096:ae88:6144]:443: wsarecv: An established connection was aborted by the software in your host machine."
# t=2025-11-13T02:25:17+0530 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=4eb792f17d2c clientid=b303b327e1037ff15a59894422fadc4c
# t=2025-11-13T02:25:27+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T02:25:37+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T02:25:48+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T02:26:00+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T02:26:14+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T02:26:32+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T02:26:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T02:27:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:28:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:28:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T02:29:28+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-11-13T02:29:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-11-13T02:30:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T02:31:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T02:31:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T02:32:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T02:33:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T02:33:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T02:34:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T02:35:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T02:35:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:36:28+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-11-13T02:36:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2025-11-13T02:37:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T02:38:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T02:38:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:39:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:40:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T02:40:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T02:41:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T02:42:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T02:42:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T02:43:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T02:44:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T02:44:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T02:45:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T02:46:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T02:46:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:47:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:48:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T02:48:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T02:49:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T02:50:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T02:50:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T02:51:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T02:52:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:52:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:53:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:54:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:54:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T02:55:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T02:56:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:56:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:57:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:58:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T02:58:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T02:59:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T03:00:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:00:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:01:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:02:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:02:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T03:03:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T03:04:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:04:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:05:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:06:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:06:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:07:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:08:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:08:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:09:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:10:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:10:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T03:11:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T03:12:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:12:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:13:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:14:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:14:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:15:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:16:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:16:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:17:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:18:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:18:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:19:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:20:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:20:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:21:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:22:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:22:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T03:23:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T03:24:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:24:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:25:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:26:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:26:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:27:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:28:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:28:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:29:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:30:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:30:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:31:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:32:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:32:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:33:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:34:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:34:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:35:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:36:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:36:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:37:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:38:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:38:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:39:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:40:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T03:40:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T03:41:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:42:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:42:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:43:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:44:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:44:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:45:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:46:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:46:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:47:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:48:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:48:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T03:49:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:50:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:50:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:51:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T03:52:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:52:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:53:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:54:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:54:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T03:55:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T03:56:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:56:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:57:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:58:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T03:58:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T03:59:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:00:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:00:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:01:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:02:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:02:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:03:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:04:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:04:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:05:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:06:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:06:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:07:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:08:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:08:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:09:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:10:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:10:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:11:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:12:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:12:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:13:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:14:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:14:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:15:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:16:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:16:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:17:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:18:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:18:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:19:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:20:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:20:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:21:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:22:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:22:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:23:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:24:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:24:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:25:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:26:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:26:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:27:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:28:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:28:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:29:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:30:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:30:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:31:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:32:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:32:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:33:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:34:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:34:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:35:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:36:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:36:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:37:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T04:38:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 13.59.170.248:443: i/o timeout"
# t=2025-11-13T04:38:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:39:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:40:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:40:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:41:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:42:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:42:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:43:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:44:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:44:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.148.88.97:443: i/o timeout"
# t=2025-11-13T04:45:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:46:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:46:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:47:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:48:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:48:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:49:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:50:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:50:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:51:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:52:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:52:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:53:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:54:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.147.185.220:443: i/o timeout"
# t=2025-11-13T04:54:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:55:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 18.217.166.135:443: i/o timeout"
# t=2025-11-13T04:56:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:56:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.21.250.75:443: i/o timeout"
# t=2025-11-13T04:57:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:58:18+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:58:58+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T04:59:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp 3.149.65.175:443: i/o timeout"
# t=2025-11-13T05:00:34+0530 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=7abd021a70d6
# t=2025-11-13T05:00:34+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to send authentication request: session closed"
# t=2025-11-13T05:53:20+0530 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d6e73d91414b clientid=b303b327e1037ff15a59894422fadc4c
# t=2025-11-13T05:53:20+0530 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=ac46ceea4a11 err="session closed"

# %%
# !cat /content/open_log.txt
# Out:
# Email ID: nukesshere@gmail.com
# Opened at: 2025-07-10 15:26:24 IST
# IP Address: 2406:7400:c8:c2ec:1529:4da2:5395:c5a3
# Open Count: 2
#
# Email ID: user123=nukesshere@gmail.com
# Opened at: 2025-07-10 15:33:06 IST
# IP Address: 2406:7400:c8:c2ec:1529:4da2:5395:c5a3
# Open Count: 1
#
# Email ID: mohammednorulashik@gmail.com
# Opened at: 2025-07-10 15:34:07 IST
# IP Address: 2406:7400:c8:c2ec:1529:4da2:5395:c5a3
# Open Count: 1

# %%
# Clear previous logs
open("/content/open_log.txt", "w").close()
print("✅ Log file cleared.")
# Out:
# ✅ Log file cleared.
